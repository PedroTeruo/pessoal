# %%
import numpy as np 
import matplotlib.pyplot as plt 

a_vals = np.array([
    [8, 1],
    [-2, 1]
])

# %% [markdown]
# item a) usar a interação inversa com p=8 e q0 = [1 1], para calcular um autovalor e um autovetor de A

# %%
#1 Fazer a interação inversa com p = 8 e q0 = [1, 1]^t

p = 8.0
q0 = np.array([1, 1])

def iteração_inversa(A,p,q0, iteracoes):
